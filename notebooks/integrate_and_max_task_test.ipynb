# %%
import sys
sys.path.insert(0, '..') 
# %load_ext autoreload
# %autoreload 2

from tasks.integrate_max_task import *
import matplotlib.pyplot as plt

# %%
# Define parameters
num_samples = 100
num_trajectories = 2
num_timesteps = 10_000
num_flips = 10
omega_process = 'binary'
omega_value = 0.005
dt = 0.5

# Generate the dataset
inputs, targets = generate_dataset(num_samples, 
                                   num_timesteps, 
                                   num_trajectories, 
                                   trajectory_type='binary', 
                                   include_initial_position=False, 
                                   integrate_max=True)

# %%
# Plot the data for the first sample
plot_data(inputs, targets, num_timesteps, sample_idx=0)

# %%
targets.shape
# Out:
# (100, 2000, 5)

# %%
positions_1 = np.arctan2(targets[0, :, 1], targets[0, :, 0])
positions_2 = np.arctan2(targets[0, :, 3], targets[0, :, 2])
plt.plot(np.max([positions_1, positions_2], axis=0))
