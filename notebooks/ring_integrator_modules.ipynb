# %%
import sys
sys.path.insert(0, '..') 
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Task: integrate independent velocities

# %%
from tasks.independent_integration_task import *

# %%
omega_range = [0.005]
num_samples = len(omega_range)
num_timesteps = 2500
num_samples = 1_000

inputs, targets = generate_dataset(num_samples, num_timesteps, constant_omega=True, omega_range=omega_range, dt=.5, sigma=0.01, alpha=0.05)
plot_data(inputs, targets, num_timesteps)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/alexnegron/modular-dynamics/notebooks/ring_integrator_modules.ipynb Cell 4 line 6
#       <a href='vscode-notebook-cell:/Users/alexnegron/modular-dynamics/notebooks/ring_integrator_modules.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> num_timesteps = 2500
#       <a href='vscode-notebook-cell:/Users/alexnegron/modular-dynamics/notebooks/ring_integrator_modules.ipynb#W3sZmlsZQ%3D%3D?line=3'>4</a> num_samples = 1_000
# ----> <a href='vscode-notebook-cell:/Users/alexnegron/modular-dynamics/notebooks/ring_integrator_modules.ipynb#W3sZmlsZQ%3D%3D?line=5'>6</a> inputs, targets = generate_dataset(num_samples, num_timesteps, constant_omega=True, omega_range=omega_range, dt=.5, sigma=0.01, alpha=0.05)
#       <a href='vscode-notebook-cell:/Users/alexnegron/modular-dynamics/notebooks/ring_integrator_modules.ipynb#W3sZmlsZQ%3D%3D?line=6'>7</a> plot_data(inputs, targets, num_timesteps)
#
# File ~/modular-dynamics/notebooks/../tasks/independent_integration_task.py:48, in generate_dataset(num_samples, num_timesteps, omega_process, dt, **kwargs)
#      46 elif omega_process == 'binary':
#      47     omegas = generate_binary_omega(num_timesteps, **kwargs)
# ---> 48 else:
#      49     raise ValueError(f'Unknown omega_process: {omega_process}')
#      51 theta0 = 0
#
# TypeError: zero_inflated_OU() got an unexpected keyword argument 'constant_omega'

# %%
num_samples = 100
num_timesteps = 3000
flip_freq = .005
refractory_period_ratio = .3
inputs, targets = generate_dataset(num_samples, num_timesteps, dt=.5, omega_process='binary', flip_freq=flip_freq, refractory_period_ratio=refractory_period_ratio)

plot_data(inputs, targets, num_timesteps)

# %%
inputs.shape
# Out:
# (100, 3000, 3)

# %%
inputs[0,...].shape
# Out:
# (3000, 3)

# %%
import numpy as np

random_number = np.random.choice([-1, 1], size=1)
print(random_number)
# Out:
# [1]

# %%
# Define parameters
num_samples = 50
num_trajectories = 2
num_timesteps = 3000
flip_freq = .005
refractory_period_ratio = .2
omega_process = 'binary'
omega_value = 0.005
dt = 0.5

# Generate the dataset
inputs, targets = generate_dataset(num_samples,
                                   num_timesteps,
                                   num_trajectories,
                                   dt=dt,
                                   flip_freq=flip_freq,
                                   omega_value=omega_value,
                                   refractory_period_ratio=refractory_period_ratio)

# %%
for i in range(num_samples):
    plt.figure()
    plt.plot(inputs[i, :, 0])
    plt.show()
